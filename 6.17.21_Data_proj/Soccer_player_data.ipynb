# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
df = pd.read_csv(r'C:\Users\smcsh\pythonclass\Python\6.17.21_Data_proj\Playa.csv',encoding='ANSI')

# %%
print (df)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age        dob  \
# ...

# %%
df1 = df.head(5)
print(df1)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age        dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  6/24/1987
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34   2/5/1985
# 2          Neymar Jr        Neymar da Silva Santos Junior   27   2/5/1992
# 3           J. Oblak                            Jan Oblak   26   1/7/1993
# 4          E. Hazard                          Eden Hazard   28   1/7/1991
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
rows = len(df.axes[0])
cols = len(df.axes[1])
print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
# Out:
# Number of Rows:  18278
# Number of Columns:  104

# %%
countries=df.groupby(['nationality'], as_index = False)['short_name'].count()
countries
# Out:
#            nationality  short_name
# 0          Afghanistan           2
# 1              Albania          43
# 2              Algeria          50
# 3               Angola          16
# 4    Antigua & Barbuda           7
# ..                 ...         ...
# 157          Venezuela          66
# 158            Vietnam           1
# 159              Wales         117
# 160             Zambia          10
# 161           Zimbabwe          12
#
# [162 rows x 2 columns]

# %%
countries=df.groupby(['nationality'], as_index = False)['short_name'].count()
countries.head(10)
# Out:
#          nationality  short_name
# 0        Afghanistan           2
# 1            Albania          43
# 2            Algeria          50
# 3             Angola          16
# 4  Antigua & Barbuda           7
# 5          Argentina         886
# 6            Armenia           8
# 7          Australia         196
# 8            Austria         319
# 9         Azerbaijan           6

# %%
countries=df.groupby(['nationality'], as_index = False)['short_name'].count()
countries_df = countries.head(5)
countries_df
# Out:
#          nationality  short_name
# 0        Afghanistan           2
# 1            Albania          43
# 2            Algeria          50
# 3             Angola          16
# 4  Antigua & Barbuda           7

# %%
countries_df.plot.bar(x='nationality', y='short_name', color="green")
plt.legend(loc="best")
plt.title("soccer players by nationality")
plt.xlabel("Nationality")
plt.ylabel("Player number")
plt.grid()

plt.show()

# %%
wage=df[['short_name','wage_eur']].nlargest(5,'wage_eur')
wage
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
wage=df[['short_name','wage_eur','value_eur']].nlargest(5,'value_eur')
wage
# Out:
#       short_name  wage_eur  value_eur
# 2      Neymar Jr    290000  105500000
# 0       L. Messi    565000   95500000
# 10     K. Mbappé    155000   93500000
# 4      E. Hazard    470000   90000000
# 5   K. De Bruyne    370000   90000000

# %%
wage.plot.bar(x='short_name', y='value_eur')
plt.legend(loc="best")
plt.title("soccer players by salary")
plt.xlabel("player")
plt.ylabel("Salary")
plt.grid()

plt.show()

# %%
germanhomies=df[df['nationality']=='Germany']
germanhomies.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...
#
#         short_name              long_name  age         dob  height_cm  \
# 6    M. ter Stegen  Marc-André ter Stegen   27   4/30/1992        187
# 31        M. Neuer           Manuel Neuer   33   3/27/1986        193
# ...

# %%
germanhomies[['short_name','height_cm']].nlargest(5,'height_cm')
# Out:
#          short_name  height_cm
# 8016      A. Seydel        199
# 1217       M. Esser        198
# 1389  L. Unnerstall        198
# 518     R. Fährmann        197
# 4449     T. Kessler        197

# %%
germanhomies[['short_name','weight_kg']].nlargest(5,'weight_kg')
# Out:
#           short_name  weight_kg
# 1389   L. Unnerstall        103
# 13576   L. Watkowiak        103
# 518      R. Fährmann         98
# 77           N. Süle         97
# 165           J. Tah         97

# %%
germanhomies[['short_name','wage_eur']].nlargest(5,'wage_eur')
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündogan    180000
# 37         M. Reus    170000

# %%
germanhomies[['short_name','wage_eur','overall']].nlargest(5,'overall')
# Out:
#        short_name  wage_eur  overall
# 6   M. ter Stegen    250000       90
# 31       M. Neuer    155000       88
# 36       T. Kroos    330000       88
# 37        M. Reus    170000       88
# 49     M. Hummels    130000       87

# %%
df[['short_name','shooting']].nlargest(5,'shooting')
# Out:
#            short_name  shooting
# 1   Cristiano Ronaldo      93.0
# 0            L. Messi      92.0
# 12            H. Kane      91.0
# 17          S. Agüero      90.0
# 19          L. Suárez      89.0

# %%
df[['short_name','defending','nationality','club']].nlargest(5,'defending')
# Out:
#       short_name  defending  nationality               club
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 16  G. Chiellini       90.0        Italy           Juventus
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
Madridhomies=df[df['club']=='Real Madrid']
Madridhomies[['short_name','wage_eur','overall']].nlargest(5,'overall')
# Out:
#       short_name  wage_eur  overall
# 4      E. Hazard    470000       91
# 8      L. Modric    340000       90
# 18  Sergio Ramos    300000       89
# 28   T. Courtois    235000       88
# 36      T. Kroos    330000       88

# %%
Madridhomies[['short_name','shooting','overall']].nlargest(5,'overall')
# Out:
#       short_name  shooting  overall
# 4      E. Hazard      83.0       91
# 8      L. Modric      76.0       90
# 18  Sergio Ramos      68.0       89
# 28   T. Courtois       NaN       88
# 36      T. Kroos      80.0       88

# %%
Madridhomies[['short_name','defending','overall']].nlargest(5,'overall')
# Out:
#           short_name  defending
# 18      Sergio Ramos       87.0
# 42          Casemiro       85.0
# 76         R. Varane       85.0
# 94          Carvajal       82.0
# 277  Nacho Fernández       81.0

# %%
Madridhomies[['short_name','nationality','overall']].nlargest(5,'overall')
# Out:
#       short_name nationality  overall
# 4      E. Hazard     Belgium       91
# 8      L. Modric     Croatia       90
# 18  Sergio Ramos       Spain       89
# 28   T. Courtois     Belgium       88
# 36      T. Kroos     Germany       88
